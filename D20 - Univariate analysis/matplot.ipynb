# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Pie Chart

# %%
sectors = ['marketing','R&D','HR','Customer Support','Sales']
budget = ['4','3','1','6','2']
plt.pie(budget, labels = sectors, autopct = '%0.1f%%')
plt.show()
